# %% [markdown]
# # Basics of Neuroimaging Analysis

# %% [markdown]
# ## This notebook is designed to introduce the fundamental concepts and techniques used in neuroimaging analysis. We will cover the following topics:
#
# ## Structural MRI:
# - Overview of structural MRI
# - Preprocessing steps (e.g., skull stripping, normalization)
# - Segmentation of brain tissues (gray matter, white matter, CSF)
#
# ## Functional MRI:
# - Overview of functional MRI
# - Preprocessing steps (e.g., motion correction, slice timing correction)
# - Statistical analysis (e.g., GLM, ROI analysis)
#
# ## Diffusion MRI:
# - Overview of diffusion MRI
# - Preprocessing steps (e.g., eddy current correction, tensor fitting)
# - Tractography and connectivity analysis

# %%
import os
import nibabel
import dipy
import nilearn
import ants
